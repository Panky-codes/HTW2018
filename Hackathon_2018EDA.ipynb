# %% [markdown]
# # EDA on 2016 data set for the Hack The Wind 2018

# %% [markdown]
# ### Changing directory

# %%
import os
os.chdir('D:\Education\Hackathon2018\pre2016')

# %% [markdown]
# ### Ingesting data with Pandas

# %%
import pandas as pd
pd.options.display.max_colwidth = 100
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
wind_signals= pd.read_csv('htw-wind-farm-1-signals-2016.csv', sep=';')
wind_errors= pd.read_csv('htw-failures-2016.csv', sep=';')
#wind_signals= pd.read_csv('D:\Education\Hackathon2018\2016\htw-wind-farm-1-signals-2016', sep=';')
#wind_signals.isnull().any()
wind_signals = wind_signals.interpolate() # interpolate to remove NA

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Function to find the relevant columns for analysis

# %%
def fin_par(par,col):
    par_str = []
    for i in col:
        if par in i:
            par_str.append(i)
    return par_str

# %% [markdown]
# ### Slicing function for the turbine data

# %%
def sli_turbine(Turbine,df):
    Tur_wind_signals =df[df['Turbine_ID'] == Turbine].sort_index(ascending=True)
    return Tur_wind_signals

# %% [markdown]
# ### Function to extract values between a given start and end time

# %%
def giv_time(df1,start_time,end_time):
    r_df1 = df1[(df1.index > start_time) & (df1.index <= end_time)]
    return r_df1

# %% [markdown]
# ### Making the timestamp as index
#    Converterd it to datetime format

# %%
wind_signals['Timestamp'] = pd.to_datetime(wind_signals['Timestamp'])
wind_signals.index = wind_signals['Timestamp']
#del wind_signals['Timestamp']

# %%
T06 = sli_turbine('T06',wind_signals) #Fn used to slice relevant turbine data
T06
# Out:
#                     Turbine_ID           Timestamp  Gen_RPM_Max  Gen_RPM_Min  \
# Timestamp
# 2016-01-01 00:00:00        T06 2016-01-01 00:00:00       1270.0       1232.8
# 2016-01-01 00:10:00        T06 2016-01-01 00:10:00       1429.7        203.9
# 2016-01-01 00:20:00        T06 2016-01-01 00:20:00       1360.5        250.3
# 2016-01-01 00:30:00        T06 2016-01-01 00:30:00       1399.2       1228.8
# 2016-01-01 00:40:00        T06 2016-01-01 00:40:00       1302.7       1225.1
# 2016-01-01 00:50:00        T06 2016-01-01 00:50:00       1298.7       1236.3
# 2016-01-01 01:00:00        T06 2016-01-01 01:00:00       1332.0       1230.7
# 2016-01-01 01:10:00        T06 2016-01-01 01:10:00       1271.1       1226.9
# 2016-01-01 01:20:00        T06 2016-01-01 01:20:00       1298.6       1233.2
# 2016-01-01 01:30:00        T06 2016-01-01 01:30:00       1280.9       1234.0
# 2016-01-01 01:40:00        T06 2016-01-01 01:40:00       1270.8       1228.8
# 2016-01-01 01:50:00        T06 2016-01-01 01:50:00       1260.5       1232.3
# 2016-01-01 02:00:00        T06 2016-01-01 02:00:00       1267.9       1230.0
# 2016-01-01 02:10:00        T06 2016-01-01 02:10:00       1259.4         82.1
# 2016-01-01 02:20:00        T06 2016-01-01 02:20:00        289.9        247.0
# 2016-01-01 02:30:00        T06 2016-01-01 02:30:00        275.8        242.4
# 2016-01-01 02:40:00        T06 2016-01-01 02:40:00        313.9        211.7
# 2016-01-01 02:50:00        T06 2016-01-01 02:50:00       1366.1        244.6
# 2016-01-01 03:00:00        T06 2016-01-01 03:00:00       1261.1        212.2
# 2016-01-01 03:10:00        T06 2016-01-01 03:10:00        236.0        117.1
# 2016-01-01 03:20:00        T06 2016-01-01 03:20:00        272.7        116.8
# 2016-01-01 03:30:00        T06 2016-01-01 03:30:00        268.2        222.3
# 2016-01-01 03:40:00        T06 2016-01-01 03:40:00        287.5        207.3
# 2016-01-01 03:50:00        T06 2016-01-01 03:50:00        299.3        199.4
# 2016-01-01 04:00:00        T06 2016-01-01 04:00:00       1341.9        240.1
# 2016-01-01 04:10:00        T06 2016-01-01 04:10:00       1411.8        155.8
# 2016-01-01 04:20:00        T06 2016-01-01 04:20:00       1262.3       1231.4
# 2016-01-01 04:30:00        T06 2016-01-01 04:30:00       1267.9        203.6
# 2016-01-01 04:40:00        T06 2016-01-01 04:40:00        277.6        162.8
# 2016-01-01 04:50:00        T06 2016-01-01 04:50:00       1330.7        185.7
# ...                        ...                 ...          ...          ...
# 2016-12-31 19:00:00        T06 2016-12-31 19:00:00       1665.2       1261.0
# 2016-12-31 19:10:00        T06 2016-12-31 19:10:00       1680.8       1405.8
# 2016-12-31 19:20:00        T06 2016-12-31 19:20:00       1643.1       1316.9
# 2016-12-31 19:30:00        T06 2016-12-31 19:30:00       1623.3       1279.0
# 2016-12-31 19:40:00        T06 2016-12-31 19:40:00       1625.0       1300.5
# 2016-12-31 19:50:00        T06 2016-12-31 19:50:00       1629.1       1282.3
# 2016-12-31 20:00:00        T06 2016-12-31 20:00:00       1602.8       1264.5
# 2016-12-31 20:10:00        T06 2016-12-31 20:10:00       1645.5       1296.2
# 2016-12-31 20:20:00        T06 2016-12-31 20:20:00       1541.2       1257.2
# 2016-12-31 20:30:00        T06 2016-12-31 20:30:00       1431.4       1236.8
# 2016-12-31 20:40:00        T06 2016-12-31 20:40:00       1398.0       1228.0
# 2016-12-31 20:50:00        T06 2016-12-31 20:50:00       1371.8       1236.3
# 2016-12-31 21:00:00        T06 2016-12-31 21:00:00       1335.2       1217.6
# 2016-12-31 21:10:00        T06 2016-12-31 21:10:00       1347.4       1222.3
# 2016-12-31 21:20:00        T06 2016-12-31 21:20:00       1425.7       1236.8
# 2016-12-31 21:30:00        T06 2016-12-31 21:30:00       1391.7       1233.8
# 2016-12-31 21:40:00        T06 2016-12-31 21:40:00       1374.1       1236.3
# 2016-12-31 21:50:00        T06 2016-12-31 21:50:00       1342.8       1225.3
# 2016-12-31 22:00:00        T06 2016-12-31 22:00:00       1473.2       1245.2
# 2016-12-31 22:10:00        T06 2016-12-31 22:10:00       1402.1       1256.3
# 2016-12-31 22:20:00        T06 2016-12-31 22:20:00       1384.4       1238.1
# 2016-12-31 22:30:00        T06 2016-12-31 22:30:00       1312.5       1227.1
# 2016-12-31 22:40:00        T06 2016-12-31 22:40:00       1336.1       1230.1
# 2016-12-31 22:50:00        T06 2016-12-31 22:50:00       1296.8       1233.9
# 2016-12-31 23:00:00        T06 2016-12-31 23:00:00       1308.9       1227.7
# 2016-12-31 23:10:00        T06 2016-12-31 23:10:00       1325.6       1234.7
# 2016-12-31 23:20:00        T06 2016-12-31 23:20:00       1336.2       1234.4
# 2016-12-31 23:30:00        T06 2016-12-31 23:30:00       1310.4       1233.1
# 2016-12-31 23:40:00        T06 2016-12-31 23:40:00       1399.6       1224.1
# 2016-12-31 23:50:00        T06 2016-12-31 23:50:00       1325.6       1234.5
#
#                      Gen_RPM_Avg  Gen_RPM_Std  Gen_Bear_Temp_Avg  \
# Timestamp
# 2016-01-01 00:00:00       1248.5          6.8               42.0
# 2016-01-01 00:10:00       1154.1        271.7               42.0
# 2016-01-01 00:20:00       1041.4        382.7               42.0
# 2016-01-01 00:30:00       1252.5         16.5               42.0
# 2016-01-01 00:40:00       1257.6         13.4               41.0
# 2016-01-01 00:50:00       1257.9         10.8               41.0
# 2016-01-01 01:00:00       1259.3         17.1               42.0
# 2016-01-01 01:10:00       1250.3          7.7               42.0
# 2016-01-01 01:20:00       1255.5         13.1               42.0
# 2016-01-01 01:30:00       1251.2          7.4               42.0
# 2016-01-01 01:40:00       1249.7          7.4               42.0
# 2016-01-01 01:50:00       1249.1          5.0               42.0
# 2016-01-01 02:00:00       1249.6          5.2               42.0
# 2016-01-01 02:10:00        904.1        478.0               42.0
# 2016-01-01 02:20:00        268.4         10.6               42.0
# 2016-01-01 02:30:00        257.3         10.3               41.0
# 2016-01-01 02:40:00        256.7         33.7               40.0
# 2016-01-01 02:50:00        951.3        441.1               38.0
# 2016-01-01 03:00:00        291.5        125.4               37.0
# 2016-01-01 03:10:00        176.2         36.6               36.0
# 2016-01-01 03:20:00        208.8         46.0               36.0
# 2016-01-01 03:30:00        245.0         12.8               35.0
# 2016-01-01 03:40:00        228.1         21.6               34.0
# 2016-01-01 03:50:00        245.8         26.4               33.0
# 2016-01-01 04:00:00        812.0        461.1               32.0
# 2016-01-01 04:10:00        710.2        489.0               32.0
# 2016-01-01 04:20:00       1248.6          5.7               32.0
# 2016-01-01 04:30:00        600.7        482.0               33.0
# 2016-01-01 04:40:00        200.9         33.8               33.0
# 2016-01-01 04:50:00        465.9        412.1               33.0
# ...                          ...          ...                ...
# 2016-12-31 19:00:00       1508.1         96.1               53.0
# 2016-12-31 19:10:00       1625.4         55.5               50.0
# 2016-12-31 19:20:00       1498.1         85.9               48.0
# 2016-12-31 19:30:00       1452.6         84.9               46.0
# 2016-12-31 19:40:00       1454.6         79.5               45.0
# 2016-12-31 19:50:00       1431.1         85.9               44.0
# 2016-12-31 20:00:00       1372.6         68.4               43.0
# 2016-12-31 20:10:00       1447.3         98.3               43.0
# 2016-12-31 20:20:00       1322.7         53.9               42.0
# 2016-12-31 20:30:00       1301.8         46.8               41.0
# 2016-12-31 20:40:00       1277.6         30.4               41.0
# 2016-12-31 20:50:00       1269.3         22.9               40.0
# 2016-12-31 21:00:00       1264.9         17.7               40.0
# 2016-12-31 21:10:00       1279.8         24.4               40.0
# 2016-12-31 21:20:00       1287.1         30.7               40.0
# 2016-12-31 21:30:00       1290.9         37.2               40.0
# 2016-12-31 21:40:00       1279.3         28.4               40.0
# 2016-12-31 21:50:00       1277.4         24.7               40.0
# 2016-12-31 22:00:00       1297.7         42.8               40.0
# 2016-12-31 22:10:00       1312.2         34.1               40.0
# 2016-12-31 22:20:00       1284.3         30.0               40.0
# 2016-12-31 22:30:00       1265.7         14.3               40.0
# 2016-12-31 22:40:00       1272.4         22.9               40.0
# 2016-12-31 22:50:00       1253.8         10.1               40.0
# 2016-12-31 23:00:00       1257.5         13.8               40.0
# 2016-12-31 23:10:00       1265.3         18.4               40.0
# 2016-12-31 23:20:00       1264.0         19.8               40.0
# 2016-12-31 23:30:00       1260.9         12.0               39.0
# 2016-12-31 23:40:00       1268.5         25.7               39.0
# 2016-12-31 23:50:00       1268.3         20.3               39.0
#
#                      Gen_Phase1_Temp_Avg  Gen_Phase2_Temp_Avg  \
# Timestamp
# 2016-01-01 00:00:00                 51.0                 52.0
# 2016-01-01 00:10:00                 51.0                 52.0
# 2016-01-01 00:20:00                 50.0                 51.0
# 2016-01-01 00:30:00                 49.0                 50.0
# 2016-01-01 00:40:00                 50.0                 50.0
# 2016-01-01 00:50:00                 50.0                 51.0
# 2016-01-01 01:00:00                 50.0                 51.0
# 2016-01-01 01:10:00                 50.0                 51.0
# 2016-01-01 01:20:00                 51.0                 51.0
# 2016-01-01 01:30:00                 51.0                 52.0
# 2016-01-01 01:40:00                 51.0                 52.0
# 2016-01-01 01:50:00                 51.0                 52.0
# 2016-01-01 02:00:00                 51.0                 52.0
# 2016-01-01 02:10:00                 51.0                 52.0
# 2016-01-01 02:20:00                 48.0                 49.0
# 2016-01-01 02:30:00                 46.0                 47.0
# 2016-01-01 02:40:00                 44.0                 45.0
# 2016-01-01 02:50:00                 43.0                 44.0
# 2016-01-01 03:00:00                 42.0                 42.0
# 2016-01-01 03:10:00                 40.0                 41.0
# 2016-01-01 03:20:00                 38.0                 39.0
# 2016-01-01 03:30:00                 37.0                 37.0
# 2016-01-01 03:40:00                 36.0                 36.0
# 2016-01-01 03:50:00                 35.0                 35.0
# 2016-01-01 04:00:00                 36.0                 36.0
# 2016-01-01 04:10:00                 37.0                 36.0
# 2016-01-01 04:20:00                 38.0                 39.0
# 2016-01-01 04:30:00                 40.0                 40.0
# 2016-01-01 04:40:00                 40.0                 40.0
# 2016-01-01 04:50:00                 40.0                 40.0
# ...                                  ...                  ...
# 2016-12-31 19:00:00                 70.0                 71.0
# 2016-12-31 19:10:00                 69.0                 70.0
# 2016-12-31 19:20:00                 68.0                 69.0
# 2016-12-31 19:30:00                 67.0                 68.0
# 2016-12-31 19:40:00                 66.0                 66.0
# 2016-12-31 19:50:00                 65.0                 65.0
# 2016-12-31 20:00:00                 63.0                 64.0
# 2016-12-31 20:10:00                 62.0                 63.0
# 2016-12-31 20:20:00                 61.0                 62.0
# 2016-12-31 20:30:00                 59.0                 61.0
# 2016-12-31 20:40:00                 58.0                 60.0
# 2016-12-31 20:50:00                 57.0                 59.0
# 2016-12-31 21:00:00                 57.0                 58.0
# 2016-12-31 21:10:00                 56.0                 57.0
# 2016-12-31 21:20:00                 56.0                 57.0
# 2016-12-31 21:30:00                 55.0                 56.0
# 2016-12-31 21:40:00                 55.0                 56.0
# 2016-12-31 21:50:00                 55.0                 56.0
# 2016-12-31 22:00:00                 55.0                 56.0
# 2016-12-31 22:10:00                 55.0                 56.0
# 2016-12-31 22:20:00                 55.0                 56.0
# 2016-12-31 22:30:00                 54.0                 55.0
# 2016-12-31 22:40:00                 54.0                 55.0
# 2016-12-31 22:50:00                 54.0                 55.0
# 2016-12-31 23:00:00                 54.0                 55.0
# 2016-12-31 23:10:00                 53.0                 55.0
# 2016-12-31 23:20:00                 53.0                 55.0
# 2016-12-31 23:30:00                 53.0                 55.0
# 2016-12-31 23:40:00                 54.0                 55.0
# 2016-12-31 23:50:00                 54.0                 55.0
#
#                      Gen_Phase3_Temp_Avg        ...          Grd_Prod_Pwr_Min  \
# Timestamp                                       ...
# 2016-01-01 00:00:00                 53.0        ...                     -17.8
# 2016-01-01 00:10:00                 52.0        ...                     -32.1
# 2016-01-01 00:20:00                 51.0        ...                     -28.6
# 2016-01-01 00:30:00                 50.0        ...                     -52.5
# 2016-01-01 00:40:00                 51.0        ...                     117.2
# 2016-01-01 00:50:00                 51.0        ...                      93.7
# 2016-01-01 01:00:00                 52.0        ...                      67.2
# 2016-01-01 01:10:00                 52.0        ...                      -4.0
# 2016-01-01 01:20:00                 52.0        ...                      25.7
# 2016-01-01 01:30:00                 52.0        ...                       7.4
# 2016-01-01 01:40:00                 52.0        ...                      15.9
# 2016-01-01 01:50:00                 52.0        ...                      19.9
# 2016-01-01 02:00:00                 53.0        ...                      28.5
# 2016-01-01 02:10:00                 53.0        ...                     -28.3
# 2016-01-01 02:20:00                 49.0        ...                     -28.5
# 2016-01-01 02:30:00                 47.0        ...                     -28.5
# 2016-01-01 02:40:00                 45.0        ...                     -28.6
# 2016-01-01 02:50:00                 44.0        ...                     -49.5
# 2016-01-01 03:00:00                 42.0        ...                     -32.4
# 2016-01-01 03:10:00                 40.0        ...                     -28.1
# 2016-01-01 03:20:00                 38.0        ...                     -28.5
# 2016-01-01 03:30:00                 37.0        ...                     -28.2
# 2016-01-01 03:40:00                 36.0        ...                     -32.4
# 2016-01-01 03:50:00                 36.0        ...                     -26.2
# 2016-01-01 04:00:00                 36.0        ...                     -49.3
# 2016-01-01 04:10:00                 36.0        ...                     -30.8
# 2016-01-01 04:20:00                 38.0        ...                     -23.0
# 2016-01-01 04:30:00                 40.0        ...                     -25.5
# 2016-01-01 04:40:00                 41.0        ...                     -25.6
# 2016-01-01 04:50:00                 40.0        ...                     -25.5
# ...                                  ...        ...                       ...
# 2016-12-31 19:00:00                 70.0        ...                     353.3
# 2016-12-31 19:10:00                 70.0        ...                     564.7
# 2016-12-31 19:20:00                 69.0        ...                     328.0
# 2016-12-31 19:30:00                 67.0        ...                     360.6
# 2016-12-31 19:40:00                 66.0        ...                     400.5
# 2016-12-31 19:50:00                 65.0        ...                     319.2
# 2016-12-31 20:00:00                 64.0        ...                     267.9
# 2016-12-31 20:10:00                 63.0        ...                     330.8
# 2016-12-31 20:20:00                 62.0        ...                     249.8
# 2016-12-31 20:30:00                 61.0        ...                     202.6
# 2016-12-31 20:40:00                 60.0        ...                     164.8
# 2016-12-31 20:50:00                 59.0        ...                     183.7
# 2016-12-31 21:00:00                 58.0        ...                     181.4
# 2016-12-31 21:10:00                 58.0        ...                     196.7
# 2016-12-31 21:20:00                 57.0        ...                     205.6
# 2016-12-31 21:30:00                 57.0        ...                     192.3
# 2016-12-31 21:40:00                 57.0        ...                     188.9
# 2016-12-31 21:50:00                 56.0        ...                     137.9
# 2016-12-31 22:00:00                 56.0        ...                     213.8
# 2016-12-31 22:10:00                 56.0        ...                     279.9
# 2016-12-31 22:20:00                 56.0        ...                     224.7
# 2016-12-31 22:30:00                 56.0        ...                     206.0
# 2016-12-31 22:40:00                 56.0        ...                     153.6
# 2016-12-31 22:50:00                 56.0        ...                      84.9
# 2016-12-31 23:00:00                 55.0        ...                     119.8
# 2016-12-31 23:10:00                 55.0        ...                     168.1
# 2016-12-31 23:20:00                 55.0        ...                     141.4
# 2016-12-31 23:30:00                 55.0        ...                     188.7
# 2016-12-31 23:40:00                 55.0        ...                     162.8
# 2016-12-31 23:50:00                 55.0        ...                     137.0
#
#                      Grd_Busbar_Temp_Avg  Rtr_RPM_Std  Grd_Prod_Pwr_Std  \
# Timestamp
# 2016-01-01 00:00:00                 37.0          0.1              36.9
# 2016-01-01 00:10:00                 37.0          2.4              38.4
# 2016-01-01 00:20:00                 37.0          3.4              27.8
# 2016-01-01 00:30:00                 37.0          0.1              48.9
# 2016-01-01 00:40:00                 37.0          0.1              52.0
# 2016-01-01 00:50:00                 37.0          0.1              60.3
# 2016-01-01 01:00:00                 37.0          0.1              65.1
# 2016-01-01 01:10:00                 37.0          0.1              51.8
# 2016-01-01 01:20:00                 37.0          0.1              62.2
# 2016-01-01 01:30:00                 37.0          0.1              59.7
# 2016-01-01 01:40:00                 38.0          0.1              39.0
# 2016-01-01 01:50:00                 38.0          0.0              22.1
# 2016-01-01 02:00:00                 38.0          0.0              41.2
# 2016-01-01 02:10:00                 38.0          4.3              39.3
# 2016-01-01 02:20:00                 37.0          0.1               2.8
# 2016-01-01 02:30:00                 37.0          0.1               2.6
# 2016-01-01 02:40:00                 36.0          0.3               2.9
# 2016-01-01 02:50:00                 35.0          3.9              28.9
# 2016-01-01 03:00:00                 35.0          1.2               4.0
# 2016-01-01 03:10:00                 35.0          0.9               2.8
# 2016-01-01 03:20:00                 34.0          0.9               2.8
# 2016-01-01 03:30:00                 34.0          0.1               2.8
# 2016-01-01 03:40:00                 33.0          0.2               3.1
# 2016-01-01 03:50:00                 33.0          0.2               3.0
# 2016-01-01 04:00:00                 32.0          4.1              10.4
# 2016-01-01 04:10:00                 32.0          4.4              48.0
# 2016-01-01 04:20:00                 32.0          0.0              23.3
# 2016-01-01 04:30:00                 32.0          4.3               6.5
# 2016-01-01 04:40:00                 32.0          0.4               2.9
# 2016-01-01 04:50:00                 32.0          3.6               3.4
# ...                                  ...          ...               ...
# 2016-12-31 19:00:00                 42.0          0.8             173.8
# 2016-12-31 19:10:00                 41.0          0.5             150.6
# 2016-12-31 19:20:00                 41.0          0.8             132.0
# 2016-12-31 19:30:00                 41.0          0.7             144.1
# 2016-12-31 19:40:00                 40.0          0.7             112.5
# 2016-12-31 19:50:00                 40.0          0.8             131.1
# 2016-12-31 20:00:00                 40.0          0.6             102.6
# 2016-12-31 20:10:00                 39.0          0.9             128.5
# 2016-12-31 20:20:00                 39.0          0.5              74.5
# 2016-12-31 20:30:00                 38.0          0.4              58.5
# 2016-12-31 20:40:00                 38.0          0.3              69.7
# 2016-12-31 20:50:00                 38.0          0.2              44.4
# 2016-12-31 21:00:00                 37.0          0.2              42.8
# 2016-12-31 21:10:00                 37.0          0.2              50.6
# 2016-12-31 21:20:00                 37.0          0.3              56.0
# 2016-12-31 21:30:00                 37.0          0.3              71.8
# 2016-12-31 21:40:00                 37.0          0.2              65.8
# 2016-12-31 21:50:00                 37.0          0.2              52.4
# 2016-12-31 22:00:00                 37.0          0.4              58.9
# 2016-12-31 22:10:00                 37.0          0.3              40.9
# 2016-12-31 22:20:00                 37.0          0.3              55.9
# 2016-12-31 22:30:00                 37.0          0.1              42.1
# 2016-12-31 22:40:00                 37.0          0.2              51.9
# 2016-12-31 22:50:00                 37.0          0.1              40.9
# 2016-12-31 23:00:00                 36.0          0.1              46.9
# 2016-12-31 23:10:00                 36.0          0.2              38.9
# 2016-12-31 23:20:00                 36.0          0.2              56.3
# 2016-12-31 23:30:00                 36.0          0.1              41.1
# 2016-12-31 23:40:00                 36.0          0.2              66.4
# 2016-12-31 23:50:00                 36.0          0.2              53.2
#
#                      Grd_Prod_ReactPwr_Avg  Grd_Prod_ReactPwr_Max  \
# Timestamp
# 2016-01-01 00:00:00                  -75.5                    0.1
# 2016-01-01 00:10:00                  -21.1                   16.4
# 2016-01-01 00:20:00                  -24.9                   22.0
# 2016-01-01 00:30:00                  -90.3                    1.2
# 2016-01-01 00:40:00                  -98.1                  -92.7
# 2016-01-01 00:50:00                  -99.4                  -86.8
# 2016-01-01 01:00:00                  -81.8                  -75.8
# 2016-01-01 01:10:00                  -74.8                    0.2
# 2016-01-01 01:20:00                  -81.3                  -73.0
# 2016-01-01 01:30:00                  -80.6                  -33.6
# 2016-01-01 01:40:00                  -80.2                  -63.9
# 2016-01-01 01:50:00                  -80.5                  388.8
# 2016-01-01 02:00:00                  -48.2                  552.0
# 2016-01-01 02:10:00                  -11.8                  430.6
# 2016-01-01 02:20:00                   -7.1                   -6.3
# 2016-01-01 02:30:00                   -7.0                   -6.3
# 2016-01-01 02:40:00                   -7.4                   -6.3
# 2016-01-01 02:50:00                    7.0                  561.5
# 2016-01-01 03:00:00                   -8.1                   -6.2
# 2016-01-01 03:10:00                   -7.0                   -6.3
# 2016-01-01 03:20:00                   -7.2                   -6.3
# 2016-01-01 03:30:00                   -7.0                   -6.3
# 2016-01-01 03:40:00                   -7.2                   -6.2
# 2016-01-01 03:50:00                   -4.9                   -2.2
# 2016-01-01 04:00:00                    5.1                  383.6
# 2016-01-01 04:10:00                   -4.5                 1000.2
# 2016-01-01 04:20:00                  -60.5                  256.8
# 2016-01-01 04:30:00                   -4.5                   28.3
# 2016-01-01 04:40:00                   -3.9                   -2.5
# 2016-01-01 04:50:00                   -1.1                   21.7
# ...                                    ...                    ...
# 2016-12-31 19:00:00                 -146.9                 -139.3
# 2016-12-31 19:10:00                 -152.0                 -145.9
# 2016-12-31 19:20:00                 -151.2                 -145.2
# 2016-12-31 19:30:00                 -148.6                 -139.8
# 2016-12-31 19:40:00                 -149.5                 -142.8
# 2016-12-31 19:50:00                 -147.4                 -139.0
# 2016-12-31 20:00:00                 -140.1                 -136.4
# 2016-12-31 20:10:00                 -139.9                 -133.6
# 2016-12-31 20:20:00                 -136.8                 -123.9
# 2016-12-31 20:30:00                 -120.4                 -114.3
# 2016-12-31 20:40:00                 -113.0                 -107.5
# 2016-12-31 20:50:00                 -111.4                 -102.4
# 2016-12-31 21:00:00                 -111.8                 -105.9
# 2016-12-31 21:10:00                 -109.9                 -104.8
# 2016-12-31 21:20:00                 -108.9                 -102.9
# 2016-12-31 21:30:00                 -109.5                 -103.9
# 2016-12-31 21:40:00                 -109.5                 -103.2
# 2016-12-31 21:50:00                 -114.3                 -106.9
# 2016-12-31 22:00:00                 -118.6                 -111.8
# 2016-12-31 22:10:00                 -112.5                 -106.9
# 2016-12-31 22:20:00                 -114.0                 -106.9
# 2016-12-31 22:30:00                 -110.4                 -106.3
# 2016-12-31 22:40:00                 -116.7                 -109.8
# 2016-12-31 22:50:00                 -111.6                 -102.7
# 2016-12-31 23:00:00                 -110.7                 -100.8
# 2016-12-31 23:10:00                 -119.4                 -109.8
# 2016-12-31 23:20:00                 -123.6                 -114.8
# 2016-12-31 23:30:00                 -114.7                 -106.3
# 2016-12-31 23:40:00                 -113.6                 -103.9
# 2016-12-31 23:50:00                 -120.2                 -112.9
#
#                      Grd_Prod_ReactPwr_Min  Grd_Prod_ReactPwr_Std  \
# Timestamp
# 2016-01-01 00:00:00                  -94.0                   16.5
# 2016-01-01 00:10:00                  -94.9                   29.7
# 2016-01-01 00:20:00                 -100.0                   35.0
# 2016-01-01 00:30:00                 -104.9                   24.8
# 2016-01-01 00:40:00                 -106.1                    3.6
# 2016-01-01 00:50:00                 -108.0                    5.5
# 2016-01-01 01:00:00                  -89.0                    3.3
# 2016-01-01 01:10:00                  -87.1                   14.7
# 2016-01-01 01:20:00                  -94.1                    4.3
# 2016-01-01 01:30:00                 -100.2                    9.2
# 2016-01-01 01:40:00                  -99.0                    8.2
# 2016-01-01 01:50:00                 -345.0                   65.4
# 2016-01-01 02:00:00                 -766.1                  280.6
# 2016-01-01 02:10:00                 -500.8                  146.3
# 2016-01-01 02:20:00                  -22.0                    2.5
# 2016-01-01 02:30:00                  -23.9                    2.3
# 2016-01-01 02:40:00                  -19.4                    2.8
# 2016-01-01 02:50:00                 -361.9                  103.2
# 2016-01-01 03:00:00                  -28.0                    3.8
# 2016-01-01 03:10:00                  -21.7                    2.4
# 2016-01-01 03:20:00                  -21.1                    2.7
# 2016-01-01 03:30:00                  -22.4                    2.4
# 2016-01-01 03:40:00                  -31.6                    2.9
# 2016-01-01 03:50:00                  -18.5                    3.1
# 2016-01-01 04:00:00                  -19.5                   38.9
# 2016-01-01 04:10:00                 -119.1                  141.0
# 2016-01-01 04:20:00                 -276.8                   80.9
# 2016-01-01 04:30:00                  -71.1                    8.5
# 2016-01-01 04:40:00                  -20.1                    3.3
# 2016-01-01 04:50:00                  -16.8                    6.6
# ...                                    ...                    ...
# 2016-12-31 19:00:00                 -155.6                    3.4
# 2016-12-31 19:10:00                 -159.2                    2.5
# 2016-12-31 19:20:00                 -158.0                    2.7
# 2016-12-31 19:30:00                 -161.1                    4.8
# 2016-12-31 19:40:00                 -158.1                    3.4
# 2016-12-31 19:50:00                 -155.0                    2.7
# 2016-12-31 20:00:00                 -146.2                    2.4
# 2016-12-31 20:10:00                 -145.1                    2.8
# 2016-12-31 20:20:00                 -148.0                    5.7
# 2016-12-31 20:30:00                 -130.0                    3.7
# 2016-12-31 20:40:00                 -119.1                    2.4
# 2016-12-31 20:50:00                 -121.0                    4.1
# 2016-12-31 21:00:00                 -118.0                    2.8
# 2016-12-31 21:10:00                 -115.0                    2.2
# 2016-12-31 21:20:00                 -115.3                    2.4
# 2016-12-31 21:30:00                 -115.0                    2.4
# 2016-12-31 21:40:00                 -116.0                    2.8
# 2016-12-31 21:50:00                 -122.0                    3.1
# 2016-12-31 22:00:00                 -125.0                    2.9
# 2016-12-31 22:10:00                 -120.0                    2.8
# 2016-12-31 22:20:00                 -122.0                    3.6
# 2016-12-31 22:30:00                 -116.0                    2.7
# 2016-12-31 22:40:00                 -122.1                    3.0
# 2016-12-31 22:50:00                 -122.0                    4.5
# 2016-12-31 23:00:00                 -125.0                    6.0
# 2016-12-31 23:10:00                 -126.5                    3.5
# 2016-12-31 23:20:00                 -131.2                    3.8
# 2016-12-31 23:30:00                 -125.0                    4.8
# 2016-12-31 23:40:00                 -125.0                    4.4
# 2016-12-31 23:50:00                 -128.1                    3.9
#
#                      Gen_Bear2_Temp_Avg  Nac_Direction_Avg
# Timestamp
# 2016-01-01 00:00:00                35.0              204.6
# 2016-01-01 00:10:00                35.0              210.5
# 2016-01-01 00:20:00                35.0              199.0
# 2016-01-01 00:30:00                35.0              205.6
# 2016-01-01 00:40:00                35.0              207.4
# 2016-01-01 00:50:00                35.0              203.2
# 2016-01-01 01:00:00                35.0              210.9
# 2016-01-01 01:10:00                35.0              204.6
# 2016-01-01 01:20:00                35.0              214.0
# 2016-01-01 01:30:00                35.0              206.7
# 2016-01-01 01:40:00                35.0              206.7
# 2016-01-01 01:50:00                35.0              206.7
# 2016-01-01 02:00:00                35.0              206.7
# 2016-01-01 02:10:00                35.0              206.7
# 2016-01-01 02:20:00                35.0              214.4
# 2016-01-01 02:30:00                34.0              206.3
# 2016-01-01 02:40:00                33.0              197.6
# 2016-01-01 02:50:00                33.0              196.9
# 2016-01-01 03:00:00                32.0              203.2
# 2016-01-01 03:10:00                32.0              205.6
# 2016-01-01 03:20:00                31.0              199.3
# 2016-01-01 03:30:00                30.0              199.0
# 2016-01-01 03:40:00                30.0              191.2
# 2016-01-01 03:50:00                29.0              177.6
# 2016-01-01 04:00:00                29.0              196.5
# 2016-01-01 04:10:00                29.0              194.8
# 2016-01-01 04:20:00                30.0              195.1
# 2016-01-01 04:30:00                31.0              202.1
# 2016-01-01 04:40:00                31.0              195.4
# 2016-01-01 04:50:00                31.0              171.7
# ...                                 ...                ...
# 2016-12-31 19:00:00                45.0               93.1
# 2016-12-31 19:10:00                44.0               93.1
# 2016-12-31 19:20:00                44.0               93.1
# 2016-12-31 19:30:00                43.0               93.1
# 2016-12-31 19:40:00                43.0               93.1
# 2016-12-31 19:50:00                42.0               93.1
# 2016-12-31 20:00:00                42.0               93.1
# 2016-12-31 20:10:00                41.0               93.1
# 2016-12-31 20:20:00                41.0               93.1
# 2016-12-31 20:30:00                40.0               93.1
# 2016-12-31 20:40:00                40.0               86.1
# 2016-12-31 20:50:00                39.0               86.1
# 2016-12-31 21:00:00                39.0               86.1
# 2016-12-31 21:10:00                39.0               86.1
# 2016-12-31 21:20:00                39.0               86.1
# 2016-12-31 21:30:00                39.0               86.1
# 2016-12-31 21:40:00                38.0               86.1
# 2016-12-31 21:50:00                38.0               86.1
# 2016-12-31 22:00:00                38.0               86.1
# 2016-12-31 22:10:00                38.0               86.1
# 2016-12-31 22:20:00                38.0               86.1
# 2016-12-31 22:30:00                38.0               86.1
# 2016-12-31 22:40:00                38.0               92.8
# 2016-12-31 22:50:00                38.0               92.8
# 2016-12-31 23:00:00                38.0               92.8
# 2016-12-31 23:10:00                38.0               92.8
# 2016-12-31 23:20:00                37.0               92.7
# 2016-12-31 23:30:00                36.0               85.0
# 2016-12-31 23:40:00                35.0               85.0
# 2016-12-31 23:50:00                34.0               90.0
#
# [50579 rows x 64 columns]

# %% [markdown]
# # T06 turbine analysis

# %%
T06_errors = sli_turbine('T06',wind_errors)
T06_errors
# Out:
#    Turbine_ID        Component            Timestamp  \
# 0         T06        GENERATOR  2016-09-04 08:08:00
# 5         T06        GENERATOR  2016-07-11 19:48:00
# 6         T06        GENERATOR  2016-10-27 16:26:00
# 9         T06  HYDRAULIC_GROUP  2016-04-04 18:53:00
# 13        T06        GENERATOR  2016-07-24 17:01:00
# 14        T06        GENERATOR  2016-10-02 17:08:00
#
#                                                                Remarks
# 0                                     High temperature generator error
# 5                                                   Generator replaced
# 6                                                   Generator replaced
# 9                                            Error in pitch regulation
# 13                                Generator temperature sensor failure
# 14  Refrigeration system and temperature sensors in generator replaced

# %%
gen_par = fin_par('Gen',T06.columns) #Fn used to find the str and par for the analysis
gentemp_par = fin_par('Temp', gen_par) #
gentemp_par
# Out:
# ['Gen_Bear_Temp_Avg',
#  'Gen_Phase1_Temp_Avg',
#  'Gen_Phase2_Temp_Avg',
#  'Gen_Phase3_Temp_Avg',
#  'Gen_SlipRing_Temp_Avg',
#  'Gen_Bear2_Temp_Avg']

# %%
T06[gentemp_par].describe()
# Out:
#        Gen_Bear_Temp_Avg  Gen_Phase1_Temp_Avg  Gen_Phase2_Temp_Avg  \
# count       50579.000000         50579.000000         50579.000000
# mean           45.007572            58.030273            59.999440
# std            17.105537            26.155916            27.788955
# min            18.000000            21.000000            21.000000
# 25%            33.000000            37.000000            38.000000
# 50%            43.000000            54.000000            55.000000
# 75%            52.000000            66.000000            69.000000
# max           205.000000           205.000000           205.000000
#
#        Gen_Phase3_Temp_Avg  Gen_SlipRing_Temp_Avg  Gen_Bear2_Temp_Avg
# count         50579.000000           50579.000000        50579.000000
# mean             58.537239              29.255630           40.271671
# std              25.945306               9.679831           14.347463
# min              21.000000              13.000000           20.000000
# 25%              37.000000              23.000000           31.000000
# 50%              55.000000              27.000000           37.000000
# 75%              68.000000              34.000000           48.000000
# max             205.000000             205.000000          205.000000

# %% [markdown]
# ### Plotting temperature values for T06 turbine

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T06.Gen_Phase1_Temp_Avg.plot(label='phase1')
T06.Gen_Phase2_Temp_Avg.plot(label='phase2')
T06.Gen_Phase3_Temp_Avg.plot(label='phase3')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Power (W)',fontsize=30)
plt.axvspan('2016-09-02 00:00:00','2016-09-04 23:00:00', color='red', alpha=0.4)
plt.axvspan('2016-10-02 00:00:00','2016-10-04 23:00:00', color='red', alpha=0.2) #2016-10-02
#axis.yaxis.set_tick_params(labelsize=15)
plt.legend(prop={'size': 30})
plt.tight_layout()
plt.ylabel("Temp")
sns.despine()

# %%
T06_errors
# Out:
#    Turbine_ID        Component            Timestamp  \
# 0         T06        GENERATOR  2016-09-04 08:08:00
# 5         T06        GENERATOR  2016-07-11 19:48:00
# 6         T06        GENERATOR  2016-10-27 16:26:00
# 9         T06  HYDRAULIC_GROUP  2016-04-04 18:53:00
# 13        T06        GENERATOR  2016-07-24 17:01:00
# 14        T06        GENERATOR  2016-10-02 17:08:00
#
#                                                                Remarks
# 0                                     High temperature generator error
# 5                                                   Generator replaced
# 6                                                   Generator replaced
# 9                                            Error in pitch regulation
# 13                                Generator temperature sensor failure
# 14  Refrigeration system and temperature sensors in generator replaced

# %% [markdown]
# ### Plotting the T06 generator temperatures around the area of failure
# - Sudden increase in either of the phases leads to a temperature failure later
#     - Should distinguish between sensor error and actual high temperature

# %%
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
sns.set_style("whitegrid")
fig, axis = plt.subplots()
T06_temerr = giv_time(T06,'2016-07-02 00:00:00','2016-10-06 00:00:00') #Fn used to extract the values bt str & end
T06_temerr.Gen_Phase1_Temp_Avg.plot(label='phase1')
T06_temerr.Gen_Phase2_Temp_Avg.plot(label='phase2')
T06_temerr.Gen_Phase3_Temp_Avg.plot(label='phase3')
axis.set_xlabel('Time',fontsize=40)
axis.set_ylabel('Gen Temperature(W)',fontsize=40)
plt.legend(prop={'size': 30})
plt.tight_layout()
plt.title("Gen Temp Vs Time",fontsize=50)
sns.despine()
plt.axvspan('2016-09-04 00:00:00','2016-09-04 23:00:00', color='red', alpha=0.2)
#plt.axvspan('2016-08-21 00:00:00', '2016-08-23 00:00:00', color='red', alpha=0.5)
#2016-09-04 08:08:00

# %%
pitch_par = fin_par('Pitch',T06.columns)
hyd_par = fin_par('Hyd',T06.columns)
print(hyd_par) 
pitch_par
# Out:
# ['Hyd_Oil_Temp_Avg']
# ['Blds_PitchAngle_Min',
#  'Blds_PitchAngle_Max',
#  'Blds_PitchAngle_Avg',
#  'Blds_PitchAngle_Std']

# %%
T06[pitch_par].describe()
# Out:
#        Blds_PitchAngle_Min  Blds_PitchAngle_Max  Blds_PitchAngle_Avg  \
# count         50579.000000         50579.000000         50579.000000
# mean              7.540891            14.730715            10.248543
# std              18.127545            20.743358            18.230517
# min              -3.300000            -2.200000            -2.300000
# 25%              -2.400000             0.300000            -1.600000
# 50%              -2.100000             5.500000             0.200000
# 75%              21.200000            24.000000            24.000000
# max              90.000000            90.000000            90.000000
#
#        Blds_PitchAngle_Std
# count         50579.000000
# mean              1.677262
# std               4.158200
# min               0.000000
# 25%               0.100000
# 50%               0.400000
# 75%               0.900000
# max              45.000000

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T06.Blds_PitchAngle_Avg.plot(label='Pitch_avg')
T06.Hyd_Oil_Temp_Avg.plot(label='Hyd_temp')
#T06.Blds_PitchAngle_Max.plot(label='Pitch_max')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Angle',fontsize=30)
#axis.yaxis.set_tick_params(labelsize=15)
plt.title("T06 pitch angle error EDA",size=30)
plt.legend(prop={'size':30})
plt.tight_layout()
sns.despine()

# %% [markdown]
# ### Pitch angle around the area of errors
# - Pitch angle and hydraulics temperature are good indicators of failure
#     - Whenever both reaches high values together, there are high chances of failure

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T06_pitcherr = giv_time(T06,'2016-02-03 00:00:00','2016-04-08 00:00:00') # Actual err on  	2016-04-04 18:53:00
T06_pitcherr.Blds_PitchAngle_Avg.plot(label='Pitch_avg')
T06_pitcherr.Hyd_Oil_Temp_Avg.plot(label='Hyd_temp')
#T06_pitcherr.Gen_Phase3_Temp_Avg.plot(label='phase3')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Angle',fontsize=30)
#axis.yaxis.set_tick_params(labelsize=15)
plt.axvspan('2016-04-04 00:00:00',' 2016-04-05 19:00:00', color='red', alpha=0.2)
plt.axvspan('2016-02-21 00:00:00',' 2016-02-22 00:00:00', color='red', alpha=0.2)
plt.title("T06 pitch angle error EDA",size=30)
plt.legend(prop={'size':30})
plt.tight_layout()
sns.despine()

# %% [markdown]
# ## T07 analysis

# %%
T07 = sli_turbine('T07',wind_signals)
T07.columns
# Out:
# Index(['Turbine_ID', 'Timestamp', 'Gen_RPM_Max', 'Gen_RPM_Min', 'Gen_RPM_Avg',
#        'Gen_RPM_Std', 'Gen_Bear_Temp_Avg', 'Gen_Phase1_Temp_Avg',
#        'Gen_Phase2_Temp_Avg', 'Gen_Phase3_Temp_Avg', 'Hyd_Oil_Temp_Avg',
#        'Gear_Oil_Temp_Avg', 'Gear_Bear_Temp_Avg', 'Nac_Temp_Avg',
#        'Rtr_RPM_Max', 'Rtr_RPM_Min', 'Rtr_RPM_Avg', 'Amb_WindSpeed_Max',
#        'Amb_WindSpeed_Min', 'Amb_WindSpeed_Avg', 'Amb_WindSpeed_Std',
#        'Amb_WindDir_Relative_Avg', 'Amb_WindDir_Abs_Avg', 'Amb_Temp_Avg',
#        'Prod_LatestAvg_ActPwrGen0', 'Prod_LatestAvg_ActPwrGen1',
#        'Prod_LatestAvg_ActPwrGen2', 'Prod_LatestAvg_TotActPwr',
#        'Prod_LatestAvg_ReactPwrGen0', 'Prod_LatestAvg_ReactPwrGen1',
#        'Prod_LatestAvg_ReactPwrGen2', 'Prod_LatestAvg_TotReactPwr',
#        'HVTrafo_Phase1_Temp_Avg', 'HVTrafo_Phase2_Temp_Avg',
#        'HVTrafo_Phase3_Temp_Avg', 'Grd_InverterPhase1_Temp_Avg',
#        'Gen_SlipRing_Temp_Avg', 'Blds_PitchAngle_Min', 'Blds_PitchAngle_Max',
#        'Blds_PitchAngle_Avg', 'Blds_PitchAngle_Std',
#        'Grd_RtrInvPhase1_Temp_Avg', 'Grd_RtrInvPhase2_Temp_Avg',
#        'Grd_RtrInvPhase3_Temp_Avg', 'Grd_Prod_Pwr_Avg', 'Grd_Prod_CosPhi_Avg',
#        'Grd_Prod_Freq_Avg', 'Grd_Prod_VoltPhse1_Avg', 'Grd_Prod_VoltPhse2_Avg',
#        'Grd_Prod_VoltPhse3_Avg', 'Grd_Prod_CurPhse1_Avg',
#        'Grd_Prod_CurPhse2_Avg', 'Grd_Prod_CurPhse3_Avg', 'Grd_Prod_Pwr_Max',
#        'Grd_Prod_Pwr_Min', 'Grd_Busbar_Temp_Avg', 'Rtr_RPM_Std',
#        'Grd_Prod_Pwr_Std', 'Grd_Prod_ReactPwr_Avg', 'Grd_Prod_ReactPwr_Max',
#        'Grd_Prod_ReactPwr_Min', 'Grd_Prod_ReactPwr_Std', 'Gen_Bear2_Temp_Avg',
#        'Nac_Direction_Avg'],
#       dtype='object')

# %%
T07_errors = sli_turbine('T07',wind_errors)
T07_errors.sort_values('Timestamp')
# Out:
#    Turbine_ID          Component            Timestamp  \
# 1         T07  GENERATOR_BEARING  2016-04-30 12:40:00
# 10        T07        TRANSFORMER  2016-07-10 03:46:00
# 7         T07        TRANSFORMER  2016-08-23 02:21:00
#
#                                                              Remarks
# 1            High temperature in generator bearing (replaced sensor)
# 10                                      High temperature transformer
# 7   High temperature transformer. Transformer refrigeration repaired

# %%
T07_trafopar = fin_par('Trafo',T07.columns)
T07_pwrpar = fin_par('Pwr',T07.columns)
T07_bearpar = fin_par('Bear',T07.columns)
#T07_trafopar
T07_bearpar
# Out:
# ['Gen_Bear_Temp_Avg', 'Gear_Bear_Temp_Avg', 'Gen_Bear2_Temp_Avg']

# %%
T07[T07_trafopar].describe()
# Out:
#        HVTrafo_Phase1_Temp_Avg  HVTrafo_Phase2_Temp_Avg  \
# count             52446.000000             52446.000000
# mean                 68.727453                76.182197
# std                  10.656684                12.368416
# min                  42.000000                46.500000
# 25%                  61.000000                68.000000
# 50%                  67.000000                72.000000
# 75%                  74.000000                81.000000
# max                 104.000000               118.000000
#
#        HVTrafo_Phase3_Temp_Avg
# count             52446.000000
# mean                 83.257493
# std                  14.571988
# min                  42.500000
# 25%                  72.000000
# 50%                  80.000000
# 75%                  92.000000
# max                 137.000000

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T07.HVTrafo_Phase1_Temp_Avg.plot(label='phase1')
T07.HVTrafo_Phase2_Temp_Avg.plot(label='phase2')
T07.HVTrafo_Phase3_Temp_Avg.plot(label='phase3')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Power (W)',fontsize=30)
plt.axvspan('2016-08-22 02:21:00','2016-08-24 02:21:00', color='red', alpha=0.2)
plt.axvspan('2016-07-09 03:46:00','2016-07-11 03:46:00', color='red', alpha=0.2) #
#axis.yaxis.set_tick_params(labelsize=15)
plt.legend(prop={'size': 30})
plt.title("T07 trafo high temperature",size=40)
plt.tight_layout()
plt.ylabel("Temp")
sns.despine()

# %% [markdown]
# - This pattern around 03rd May gives an indictation for the future high temp event in 10th of july

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T07_trafoerr = giv_time(T07,'2016-05-01 02:21:00','2016-05-11 02:21:00') # Actual err on 2016-07-10 03:46:00 & 2016-08-23 02:21:00
T07_trafoerr.HVTrafo_Phase3_Temp_Avg.plot(label='HV trafo temp')
#T07_trafoerr.Amb_WindSpeed_Avg.plot(label='Amb wind speed')
#T07_trafoerr.HVTrafo_Phase1_Temp_Avg.plot(label='phase3')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Temperaure',fontsize=30)
#axis.yaxis.set_tick_params(labelsize=15)
plt.axvspan('2016-05-03 03:46:00','2016-05-04 03:47:00', color='red', alpha=0.2) #
#plt.axvspan('2016-02-21 00:00:00',' 2016-02-22 00:00:00', color='red', alpha=0.2)
plt.title("T07 trafo high temperature",size=40)
plt.legend(prop={'size':30})
plt.tight_layout()
sns.despine()

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T07_trafoerr = giv_time(T07,'2016-08-22 02:21:00','2016-08-24 02:21:00') # Actual err on 2016-07-10 03:46:00 & 2016-08-23 02:21:00
T07_trafoerr.HVTrafo_Phase3_Temp_Avg.plot(label='HV trafo temp')
#T07_trafoerr.Amb_WindSpeed_Avg.plot(label='Amb wind speed')
#T07_trafoerr.HVTrafo_Phase1_Temp_Avg.plot(label='phase3')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Temperaure',fontsize=30)
plt.axvspan('2016-08-23 01:21:00','2016-08-23 03:21:00', color='red', alpha=0.2) #
#plt.axvspan('2016-02-21 00:00:00',' 2016-02-22 00:00:00', color='red', alpha=0.2)
plt.title("T07 trafo high temperature",size=40)
plt.legend(prop={'size':30})
plt.tight_layout()
sns.despine()

# %% [markdown]
# # T09 analysis

# %%
T09 = sli_turbine('T09',wind_signals)
#T09.columns

# %%
T09_errors = sli_turbine('T09',wind_errors)
T09_errors.sort_values('Timestamp')
# Out:
#    Turbine_ID          Component            Timestamp  \
# 2         T09  GENERATOR_BEARING  2016-06-07 16:59:00
# 3         T09  GENERATOR_BEARING  2016-08-22 18:25:00
# 15        T09            GEARBOX  2016-10-11 08:06:00
# 11        T09  GENERATOR_BEARING  2016-10-17 09:19:00
#
#                                   Remarks
# 2   High tempemperature generator bearing
# 3      High temperature generator bearing
# 15                       Gearbox repaired
# 11            Generator bearings replaced

# %%
T09_bearpar = fin_par('Bear',T09.columns)
#T09_bearpar
T09_pwrpar = fin_par('Pwr',T09.columns)
T09_pwrpar
# Out:
# ['Prod_LatestAvg_ActPwrGen0',
#  'Prod_LatestAvg_ActPwrGen1',
#  'Prod_LatestAvg_ActPwrGen2',
#  'Prod_LatestAvg_TotActPwr',
#  'Prod_LatestAvg_ReactPwrGen0',
#  'Prod_LatestAvg_ReactPwrGen1',
#  'Prod_LatestAvg_ReactPwrGen2',
#  'Prod_LatestAvg_TotReactPwr',
#  'Grd_Prod_Pwr_Avg',
#  'Grd_Prod_Pwr_Max',
#  'Grd_Prod_Pwr_Min',
#  'Grd_Prod_Pwr_Std',
#  'Grd_Prod_ReactPwr_Avg',
#  'Grd_Prod_ReactPwr_Max',
#  'Grd_Prod_ReactPwr_Min',
#  'Grd_Prod_ReactPwr_Std']

# %%
T09[['Gen_Bear_Temp_Avg','Gen_Bear2_Temp_Avg']].describe()
# Out:
#        Gen_Bear_Temp_Avg  Gen_Bear2_Temp_Avg
# count       52379.000000        52379.000000
# mean           52.415217           45.298268
# std            19.980214           16.730820
# min            18.000000           19.000000
# 25%            36.000000           32.000000
# 50%            51.000000           44.000000
# 75%            67.000000           55.000000
# max            99.000000          205.000000

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T09.Grd_Prod_Pwr_Avg.plot(label='Gen 2')
#T09.Gen_Bear_Temp_Avg.plot(label='Gen 1')
T09.Prod_LatestAvg_TotActPwr.plot(label='phase3')
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Temperature (W)',fontsize=30)
plt.axvspan('2016-06-06 16:59:00','2016-06-08 16:59:00', color='red', alpha=0.2) # 2016-06-07 16:59:00
plt.axvspan('2016-08-21 18:25:00','2016-08-23 18:25:00', color='red', alpha=0.2) # 2016-08-22 18:25:00
#axis.yaxis.set_tick_params(labelsize=15)
plt.legend(prop={'size': 30})
plt.title("T09 Gen bear high temperature",size=40)
plt.tight_layout()
plt.ylabel("Temp")
sns.despine()

# %%
plt.rcParams['figure.figsize'] =(30,15)
sns.set_style("whitegrid")
plt.rc('xtick', labelsize=25)
plt.rc('ytick', labelsize=25)
fig, axis = plt.subplots()
T09_generr = giv_time(T09,'2016-06-06 16:59:00','2016-06-08 16:59:00') # 
#T09_generr.Gen_Bear2_Temp_Avg.plot(label='Gen bear 2 temp')
T09_generr.Gen_Bear_Temp_Avg.plot(label='Gen bear 1 temp')
T09_generr.Amb_WindSpeed_Avg.plot(label='RPM') #Gen_RPM_Avg
axis.set_xlabel('Time',fontsize=30)
axis.set_ylabel('Temperaure',fontsize=30)
plt.axvspan('2016-06-07 15:59:00','2016-06-07 17:59:00', color='red', alpha=0.2) #
#plt.axvspan('2016-02-21 00:00:00',' 2016-02-22 00:00:00', color='red', alpha=0.2)
plt.title("T09 Gen bear high temperature",size=40)
plt.legend(prop={'size':30})
plt.tight_layout()
sns.despine()
